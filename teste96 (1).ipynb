# %%
# !pip install --upgrade protobuf tensorflow-metadata tensorflow-datasets
# Out:
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (5.29.6)
# Collecting protobuf
#   Downloading protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.12/dist-packages (1.21.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.12/dist-packages (4.9.10)
# Requirement already satisfied: absl-py<3.0.0,>=0.9 in /usr/local/lib/python3.12/dist-packages (from tensorflow-metadata) (1.4.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.12/dist-packages (from tensorflow-metadata) (1.75.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (0.8.3)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (0.1.10)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.14.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (4.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (2.0.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (2.32.4)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (0.1.8)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (3.3.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (4.67.3)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (2.2.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2025.3.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2026.5.20)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->tensorflow-datasets) (26.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser~=0.15 in /usr/local/lib/python3.12/dist-packages (from simple_parsing->tensorflow-datasets) (0.18.0)
# Downloading protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.1/327.1 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-discoveryengine 0.13.12 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 7.35.1 which is incompatible.
# google-cloud-aiplatform 1.157.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 7.35.1 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 7.35.1 which is incompatible.
# Successfully installed protobuf-7.35.1

# %%
import os
import tensorflow as tf
import tensorflow_datasets as tfds
import cv2
import numpy as np
import shutil

base_dir = '/content/dataset_industrial_limto'
if os.path.exists(base_dir):
    shutil.rmtree(base_dir)

os.makedirs(os.path.join(base_dir, 'person'), exist_ok=True)
os.makedirs(os.path.join(base_dir, 'no-person'), exist_ok=True)

print("📥 Baixando subset oficial do Pascal VOC (Validado Cientificamente)...")
ds_bruto, info = tfds.load('voc/2012', split='train+validation', with_info=True)

count_p = 0
count_np = 0
limite_imagens = 400

print("✂️ Filtrando e extraindo apenas a categoria 'person'...")
for exemplo in ds_bruto:
    imagem_tensor = exemplo['image']
    objetos_classes = exemplo['objects']['label'].numpy()

    tem_pessoa = 14 in objetos_classes

    img_np = imagem_tensor.numpy()
    img_bgr = cv2.cvtColor(img_np, cv2.COLOR_RGB2BGR)

    if tem_pessoa and count_p < (limite_imagens // 2):
        nome_arquivo = f"person_{count_p}.jpg"
        cv2.imwrite(os.path.join(base_dir, 'person', nome_arquivo), img_bgr)
        count_p += 1
    elif not tem_pessoa and count_np < (limite_imagens // 2):
        nome_arquivo = f"no_person_{count_np}.jpg"
        cv2.imwrite(os.path.join(base_dir, 'no-person', nome_arquivo), img_bgr)
        count_np += 1

    if count_p >= (limite_imagens // 2) and count_np >= (limite_imagens // 2):
        break

print(f"\n Dataset criado com sucesso e 100% livre de erros humanos!")
print(f"-> Imagens com Pessoas Reais (Garantido): {count_p}")
print(f"-> Imagens de Ambientes Vazios (Garantido): {count_np}")
# Out:
# 📥 Baixando subset oficial do Pascal VOC (Validado Cientificamente)...
# ✂️ Filtrando e extraindo apenas a categoria 'person'...
#
#  Dataset criado com sucesso e 100% livre de erros humanos!
# -> Imagens com Pessoas Reais (Garantido): 200
# -> Imagens de Ambientes Vazios (Garantido): 200

# %%
import tensorflow as tf

# ==========================================
# 1. DATASET COM 96x96
# ==========================================
IMG_SIZE = (96, 96)  # <- mudou aqui
BATCH_SIZE = 32
novo_base_dir = '/content/dataset_industrial_limto'

train_ds = tf.keras.utils.image_dataset_from_directory(
    novo_base_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    shuffle=True,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    novo_base_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    shuffle=True,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)

train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds   = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

# ==========================================
# 2. MODELO COM MOBILENETV2 alpha=0.35
# ==========================================
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(96, 96, 3),
    include_top=False,
    weights='imagenet',
    alpha=0.35
)
base_model.trainable = False  # congela pra fase 1

inputs = tf.keras.Input(shape=(96, 96, 3))
x = tf.keras.applications.mobilenet_v2.preprocess_input(inputs)
x = base_model(x, training=False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.3)(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model_tl = tf.keras.Model(inputs, outputs)
model_tl.summary()
# Out:
# Found 400 files belonging to 2 classes.
# Using 320 files for training.
# Found 400 files belonging to 2 classes.
# Using 80 files for validation.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_0.35_96             │ (None, 3, 3, 1280)     │       410,208 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 411,489 (1.57 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 410,208 (1.56 MB)

# %% [markdown]
# ## 5. Inspeção de Formato e Visualização de Amostras Reais
# Verificamos as dimensões das matrizes geradas pelo TensorFlow e printamos as primeiras 8 imagens para garantir visualmente que o dataset está correto e sem erros de rótulo.

# %%
import matplotlib.pyplot as plt

class_names_bin = {0.0: "no-person", 1.0: "person"}

for imagens_lote, labels_lote in train_ds.take(1):
    shape_imagens_treino = imagens_lote.shape
    shape_labels_treino = labels_lote.shape

print("The image data batch shape is: (#images_per_batch, img_height, img_width, #channels)")
print(f"-> Imagens de Treino: {shape_imagens_treino}")
print("\nThe labels batch shape is: (#images_per_batch, binary_target)")
print(f"-> Rótulos de Treino: {shape_labels_treino}\n")

print(" Exibindo amostras do novo lote (Garantido livre de erros):")
plt.figure(figsize=(12, 6))
for i in range(8):
    plt.subplot(2, 4, i + 1)

    img_render = imagens_lote[i].numpy().astype("uint8")
    label_val = labels_lote[i].numpy()[0]

    plt.imshow(img_render)
    plt.title(f"Label: {label_val} ({class_names_bin[label_val].upper()})", fontsize=10, weight='bold')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# The image data batch shape is: (#images_per_batch, img_height, img_width, #channels)
# -> Imagens de Treino: (32, 96, 96, 3)
#
# The labels batch shape is: (#images_per_batch, binary_target)
# -> Rótulos de Treino: (32, 1)
#
#  Exibindo amostras do novo lote (Garantido livre de erros):

# %% [markdown]
# ## 6. Arquitetura da Rede Neural (Transfer Learning)
# Instanciamos a MobileNetV2 congelada, adicionamos o bloco avançado de Data Augmentation para simular variações de luz/contraste do ambiente industrial e estruturamos o topo denso da rede.

# %%
from tensorflow.keras import layers, models, applications

# 1. Camada de Input adaptada para a nova resolução
inputs = layers.Input(shape=(96, 96, 3))

# 2. DATA AUGMENTATION (A mágica contra camuflagem e oclusão!)
# Nota: Só funciona durante o .fit(), o TensorFlow desativa automaticamente no .predict() da webcam.
x = layers.RandomFlip("horizontal")(inputs) # Ajuda se a pessoa estiver virada para o outro lado
x = layers.RandomRotation(0.15)(x)         # Ajuda se a câmera ou a pessoa estiverem inclinadas
x = layers.RandomZoom(0.2)(x)             # Força a rede a aprender a ver pessoas de longe e de perto
x = layers.RandomContrast(0.2)(x)         # Cria variações de sombra e iluminação artificial

# 3. Pré-processador nativo da MobileNetV2
x = applications.mobilenet_v2.preprocess_input(x)

# 4. Modelo Base Congelado
base_model = applications.MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(96, 96, 3),
    alpha=0.35              # <- adiciona isso
)
base_model.trainable = False
x = base_model(x, training=False)

# 5. Cabeça de Classificação Industrial Avançada
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

# Monta o modelo final reconstruído
model_tl = models.Model(inputs, outputs)
model_tl.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip (RandomFlip)        │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 96, 96, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast                 │ (None, 96, 96, 3)      │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract_1 (Subtract)           │ (None, 96, 96, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_0.35_96             │ (None, 3, 3, 1280)     │       410,208 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 574,305 (2.19 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 410,208 (1.56 MB)

# %% [markdown]
# ## 7. Processo de Treinamento e Fine-Tuning
# Executamos o treinamento em duas etapas: primeiro o Warm-up das camadas densas superiores, seguido pelo descongelamento das últimas 20 camadas convolucionais da MobileNetV2 com uma taxa de aprendizado reduzida.

# %%
# ==========================================
# CONFIGURAÇÃO DA FASE 1 (Warm-up)
# ==========================================
model_tl.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy')]
)

callback_fase1 = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

print("Fase 1: Ajustando camadas de classificação superiores...")
# CORREÇÃO: Adicionamos o "history_fase1 =" aqui!
history_fase1 = model_tl.fit(train_ds, validation_data=val_ds, epochs=5, callbacks=[callback_fase1])


# ==========================================
# CONFIGURAÇÃO DA FASE 2 (Fine-Tuning)
# ==========================================
print("\nDestravando apenas as últimas 5 camadas finais para especialização industrial...")
base_model.trainable = True

# CORREÇÃO: Mantivemos -5 (para não dar Overfitting com as 400 imagens)
for layer in base_model.layers[:-5]:
    layer.trainable = False

model_tl.compile(
    # CORREÇÃO: Taxa de aprendizado microscópica (1e-5) para um ajuste super seguro
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
    loss='binary_crossentropy',
    metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy')]
)

callback_fase2 = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

print("Fase 2: Iniciando Fine-Tuning profundo...")
# CORREÇÃO: Mudamos o nome da variável para "history_fase2 =" aqui!
history_fase2 = model_tl.fit(train_ds, validation_data=val_ds, epochs=15, callbacks=[callback_fase2])
# Out:
# Fase 1: Ajustando camadas de classificação superiores...
# Epoch 1/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 387ms/step - accuracy: 0.5344 - loss: 0.8527 - val_accuracy: 0.7125 - val_loss: 0.5628
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6969 - loss: 0.6802 - val_accuracy: 0.7625 - val_loss: 0.5003
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7219 - loss: 0.6128 - val_accuracy: 0.7500 - val_loss: 0.4709
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7031 - loss: 0.5660 - val_accuracy: 0.7625 - val_loss: 0.4733
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.7563 - loss: 0.4897 - val_accuracy: 0.7500 - val_loss: 0.4623
#
# Destravando apenas as últimas 5 camadas finais para especialização industrial...
# Fase 2: Iniciando Fine-Tuning profundo...
# Epoch 1/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 361ms/step - accuracy: 0.7250 - loss: 0.5677 - val_accuracy: 0.7500 - val_loss: 0.4598
# Epoch 2/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.7500 - loss: 0.5352 - val_accuracy: 0.7500 - val_loss: 0.4581
# Epoch 3/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.7500 - loss: 0.5321 - val_accuracy: 0.7500 - val_loss: 0.4573
# Epoch 4/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.7375 - loss: 0.4927 - val_accuracy: 0.7375 - val_loss: 0.4566
# Epoch 5/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.7500 - loss: 0.5325 - val_accuracy: 0.7500 - val_loss: 0.4563
# Epoch 6/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7844 - loss: 0.4902 - val_accuracy: 0.7375 - val_loss: 0.4565
# Epoch 7/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7156 - loss: 0.5586 - val_accuracy: 0.7250 - val_loss: 0.4571
# Epoch 8/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.7469 - loss: 0.5735 - val_accuracy: 0.7250 - val_loss: 0.4580
# Epoch 9/15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7156 - loss: 0.5704 - val_accuracy: 0.7250 - val_loss: 0.4587

# %% [markdown]
# ## 9. Performance Curve Charts
# Exibimos a evolução histórica das métricas de Acurácia e Perda ao longo das épocas computacionais processadas.

# %%
import matplotlib.pyplot as plt

# 1. Juntando as métricas das duas fases
acc = history_fase1.history['accuracy'] + history_fase2.history['accuracy']
val_acc = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']

loss = history_fase1.history['loss'] + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss'] + history_fase2.history['val_loss']

# Época exata onde ocorreu a transição para marcar no gráfico
epoca_transicao = len(history_fase1.history['accuracy']) - 1

# 2. Plotando o Gráfico Científico
plt.figure(figsize=(14, 5))

# Curva de Acurácia
plt.subplot(1, 2, 1)
plt.plot(acc, label='Treino', linewidth=2, color='#1f77b4')
plt.plot(val_acc, label='Validação', linewidth=2, color='#ff7f0e')
plt.axvline(x=epoca_transicao, color='red', linestyle='--', label='Início do Fine-Tuning')
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Acurácia', fontsize=12)
plt.title('Curvas de Acurácia (Treino Completo)', fontsize=14, weight='bold')
plt.legend(loc='lower right')
plt.grid(True, linestyle=':', alpha=0.7)

# Curva de Loss
plt.subplot(1, 2, 2)
plt.plot(loss, label='Treino', linewidth=2, color='#1f77b4')
plt.plot(val_loss, label='Validação', linewidth=2, color='#ff7f0e')
plt.axvline(x=epoca_transicao, color='red', linestyle='--', label='Início do Fine-Tuning')
plt.xlabel('Épocas', fontsize=12)
plt.ylabel('Loss (Erro)', fontsize=12)
plt.title('Curvas de Loss (Treino Completo)', fontsize=14, weight='bold')
plt.legend(loc='upper right')
plt.grid(True, linestyle=':', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Statistical Model Evaluation
# Extraímos a matriz de confusão e o relatório discriminado por classe para aferir o poder preditivo final do classificador binário industrial.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

y_true, y_pred = [], []
for images, labels in val_ds:
    preds = model_tl.predict(images, verbose=0)
    y_true.extend(labels.numpy().flatten())
    y_pred.extend((preds > 0.5).astype(int).flatten())

print("\n--- MATRIZ DE CONFUSÃO BRUTA ---")
matriz = confusion_matrix(np.array(y_true), np.array(y_pred))
print(matriz)

print("\n--- RELATÓRIO DE CLASSIFICAÇÃO INDUSTRIAL ---")
print(classification_report(np.array(y_true), np.array(y_pred), target_names=['no-person', 'person']))

plt.figure(figsize=(7, 5))
sns.heatmap(matriz, cmap='Blues', annot=True, fmt='g',
            xticklabels=['no-person', 'person'],
            yticklabels=['no-person', 'person'])
plt.xlabel('Previsões do Modelo MobileNetV2')
plt.ylabel('Valores Reais (Pascal VOC)')
plt.title('Matriz de Confusão Consolidada')
plt.show()
# Out:
# --- MATRIZ DE CONFUSÃO BRUTA ---
# [[28 10]
#  [10 32]]
#
# --- RELATÓRIO DE CLASSIFICAÇÃO INDUSTRIAL ---
#               precision    recall  f1-score   support
#
#    no-person       0.74      0.74      0.74        38
#       person       0.76      0.76      0.76        42
#
#     accuracy                           0.75        80
#    macro avg       0.75      0.75      0.75        80
# weighted avg       0.75      0.75      0.75        80

# %% [markdown]
# ## 11. Testing Model on New Images (Letterboxing)
# Criamos uma rotina de teste interativo que aceita uploads manuais de imagens e aplica a técnica de acolchoamento proporcional (*Letterboxing*) antes de alimentar a malha lógica da MobileNetV2.

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# 1. Função JavaScript para acessar a webcam pelo navegador
def capturar_webcam(filename='foto_webcam.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capturar Imagem';
      // Estilizando o botão para ficar visível
      capture.style.padding = '10px 20px';
      capture.style.fontSize = '16px';
      capture.style.backgroundColor = '#4CAF50';
      capture.style.color = 'white';
      capture.style.border = 'none';
      capture.style.cursor = 'pointer';
      capture.style.marginBottom = '10px';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';

      // Pede permissão para usar a câmera do dispositivo
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Espera o clique no botão
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# 2. Sua função matemática de Letterboxing (Intacta)
def resize_with_padding(img, target_size=(96, 96)):
    h, w = img.shape[:2]
    target_w, target_h = target_size
    scale = min(target_w/w, target_h/h)
    new_w, new_h = int(w * scale), int(h * scale)
    img_resized = cv2.resize(img, (new_w, new_h))
    result = np.zeros((target_h, target_w, 3), dtype=np.uint8)
    x_offset = (target_w - new_w) // 2
    y_offset = (target_h - new_h) // 2
    result[y_offset:y_offset+new_h, x_offset:x_offset+new_w] = img_resized
    return result

# ==========================================
# 3. ROTINA PRINCIPAL DE TESTE
# ==========================================
try:
  print("LIGANDO A CÂMERA... (Permita o acesso no seu navegador)")
  filename = capturar_webcam()
  print("✅ Foto capturada com sucesso! Analisando...")

  # Lê a imagem salva
  img_bgr = cv2.imread(filename)
  img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

  # Aplica o seu pipeline
  IMG_SIZE = (96, 96)
  img_square = resize_with_padding(img_rgb, target_size=IMG_SIZE)
  img_array = np.expand_dims(img_square, axis=0).astype(np.float32)

  # Previsão da Inteligência Artificial
  probability = model_tl.predict(img_array, verbose=0)[0][0]
  LIMIAR_DE_DECISAO = 0.5

  # Renderização do Resultado
  plt.figure(figsize=(10, 4))
  plt.subplot(1, 2, 1)
  plt.imshow(img_rgb)
  plt.title("Visão da Webcam")
  plt.axis('off')

  plt.subplot(1, 2, 2)
  plt.imshow(img_square)
  plt.axis('off')

  if probability > LIMIAR_DE_DECISAO:
      cor = 'green'
      label_text = f'PERSON ({probability*100:.2f}%)'
  else:
      cor = 'red'
      label_text = f'NO-PERSON (Confiança: {probability*100:.2f}%)'

  plt.title(f"Previsão: {label_text}", color=cor, fontsize=12, weight='bold')
  plt.tight_layout()
  plt.show()

except Exception as err:
  print("❌ Erro ao acessar a câmera. Certifique-se de que o navegador tem permissão.")
  print(str(err))
# Out:
# LIGANDO A CÂMERA... (Permita o acesso no seu navegador)
# ✅ Foto capturada com sucesso! Analisando...

# %% [markdown]
# ## 12. Saving Model for Netron Structural Diagram
# Exportamos o artefato final empacotado no formato moderno `.keras` para renderização estrutural das camadas de convolução.

# %%
# Salva o modelo no formato padrão do Keras
model_tl.save('modelo_industrial.h5')

# Baixa o arquivo para o seu computador
from google.colab import files
files.download('modelo_industrial.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Salva no novo formato nativo do Keras 3 que não quebra operações matemáticas
model_tl.save('modelo_industrial.keras')

# Baixa o novo arquivo para o seu computador
from google.colab import files
files.download('modelo_industrial.keras')

# %%
import tensorflow as tf

# ==========================================
# PASSO 1 — Salva e converte pra TFLite
# ==========================================
model_tl.save('modelo_industrial.keras')

converter = tf.lite.TFLiteConverter.from_keras_model(model_tl)
tflite_f32 = converter.convert()

with open('modelo_industrial.tflite', 'wb') as f:
    f.write(tflite_f32)

size_f32 = len(tflite_f32) / 1024
print(f'TFLite float32: {size_f32:.1f} KB')
# Out:
# Saved artifact at '/tmp/tmpcox4t6th'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name='keras_tensor_161')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   136157308275024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308275984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308275600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308275216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308274064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308274256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989374288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989374096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146188560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146188944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146188368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146188752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146204112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146204496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146204304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856637008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856633936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856637968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856637584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856638928: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite float32: 2198.0 KB

# %%
# ==========================================
# PASSO 2 — Converte pra array C (.h)
# ==========================================
def tflite_to_c_array(tflite_bytes, var_name='modelo_industrial'):
    c_array = ', '.join([f'0x{b:02x}' for b in tflite_bytes])
    return f"""// Modelo MobileNetV2 — Detecção de Pessoa (binário)
// Tamanho : {len(tflite_bytes)} bytes ({len(tflite_bytes)/1024:.1f} KB)
// Entrada : float32 [1][224][224][3]
// Saída   : float32 [1][1]  — >0.5 = pessoa, <=0.5 = sem pessoa

#ifndef MODELO_INDUSTRIAL_H
#define MODELO_INDUSTRIAL_H
#include <stdint.h>
const unsigned char {var_name}[] = {{
  {c_array}
}};
const unsigned int {var_name}_len = {len(tflite_bytes)};
#endif
"""

header = tflite_to_c_array(tflite_f32)
with open('modelo_industrial.h', 'w') as f:
    f.write(header)

print('✓ modelo_industrial.h gerado')
print(f'  Tamanho: {len(tflite_f32)} bytes ({len(tflite_f32)/1024:.1f} KB)')
# Out:
# ✓ modelo_industrial.h gerado
#   Tamanho: 2250760 bytes (2198.0 KB)

# %%
# ==========================================
# PASSO 3 — Baixa os arquivos
# ==========================================
from google.colab import files
files.download('modelo_industrial.tflite')
files.download('modelo_industrial.h')

# %%
# ==========================================
# PASSO 1.5 — Quantização INT8
# ==========================================

def representative_dataset():
    for images, _ in train_ds.take(100):  # pega 100 batches
        for img in images:
            img_array = np.expand_dims(img, axis=0).astype(np.float32)
            yield [img_array]

converter_int8 = tf.lite.TFLiteConverter.from_keras_model(model_tl)
converter_int8.optimizations = [tf.lite.Optimize.DEFAULT]
converter_int8.representative_dataset = representative_dataset
converter_int8.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter_int8.inference_input_type  = tf.int8
converter_int8.inference_output_type = tf.int8

tflite_int8 = converter_int8.convert()

with open('modelo_industrial_int8.tflite', 'wb') as f:
    f.write(tflite_int8)

print(f'Float32 : {len(tflite_f32)/1024:.1f} KB')
print(f'INT8    : {len(tflite_int8)/1024:.1f} KB')
print(f'Redução : {(1 - len(tflite_int8)/len(tflite_f32))*100:.1f}%')

from google.colab import files
files.download('modelo_industrial_int8.tflite')
# Out:
# Saved artifact at '/tmp/tmp8y8na96r'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name='keras_tensor_161')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   136157308275024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308275984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308275600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308275216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308274064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308274256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308277904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308279824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308280784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308281744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308282704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308283664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308284624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308287504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308286544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308288656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136157308285584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989358160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989359504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989360464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989361424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989362384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989363344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989364304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989366224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989367184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989368144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989369104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989370064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989374288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989372944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989373520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989374096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156989371024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146188560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146188944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146188368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146188752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146189712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146190672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146191632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146192592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146193552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146194512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146195472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146196432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146197392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146198352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146199312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146200272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146204112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146204496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146202192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146203728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146204304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136156146201232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856634512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856637008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856633936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856637968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856636240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856635280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856637584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136155856638928: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Float32 : 2198.0 KB
# INT8    : 771.3 KB
# Redução : 64.9%

# %%
# Diagnóstico — roda isso antes do treino
for images, labels in train_ds.take(1):
    print("Shape do batch:", images.shape)  # deve mostrar (32, 96, 96, 3)

print("Input do modelo:", model_tl.input_shape)  # deve mostrar (None, 96, 96, 3)
# Out:
# Shape do batch: (32, 96, 96, 3)
# Input do modelo: (None, 96, 96, 3)

# %%
def tflite_to_c_array(tflite_bytes, var_name='modelo_industrial'):
    c_array = ', '.join([f'0x{b:02x}' for b in tflite_bytes])
    return f"""// Modelo MobileNetV2 0.35 — Detecção de Pessoa (binário)
// Tamanho : {len(tflite_bytes)} bytes ({len(tflite_bytes)/1024:.1f} KB)
// Entrada : int8 [1][96][96][3]
// Saída   : int8 [1][1]  — >0 = pessoa, <=0 = sem pessoa

#ifndef MODELO_INDUSTRIAL_H
#define MODELO_INDUSTRIAL_H
#include <stdint.h>
const unsigned char modelo_industrial[] = {{
  {c_array}
}};
const unsigned int modelo_industrial_len = {len(tflite_bytes)};
#endif
"""

header = tflite_to_c_array(tflite_int8)
with open('modelo_industrial.h', 'w') as f:
    f.write(header)

print('✓ modelo_industrial.h gerado')
print(f'  Tamanho: {len(tflite_int8)/1024:.1f} KB')

from google.colab import files
files.download('modelo_industrial_int8.tflite')
files.download('modelo_industrial.h')
# Out:
# ✓ modelo_industrial.h gerado
#   Tamanho: 771.3 KB
